# %% [markdown]
# <a href="https://colab.research.google.com/github/LifeofAGeek/100-days-of-Applied-AI/blob/master/DM_Assignment(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv("sobar-72.csv")

# %%
data.describe()
# Out:
#        behavior_sexualRisk  behavior_eating  behavior_personalHygine  \
# count            72.000000        72.000000                72.000000
# mean              9.666667        12.791667                11.083333
# std               1.186782         2.361293                 3.033847
# min               2.000000         3.000000                 3.000000
# 25%              10.000000        11.000000                 9.000000
# 50%              10.000000        13.000000                11.000000
# 75%              10.000000        15.000000                14.000000
# max              10.000000        15.000000                15.000000
#
#        intention_aggregation  intention_commitment  attitude_consistency  \
# count              72.000000             72.000000             72.000000
# mean                7.902778             13.347222              7.180556
# std                 2.738148              2.374511              1.522844
# ...

# %%
data[["norm_fulfillment" ,"perception_severity" ,"perception_vulnerability"]].corr()
# Out:
#                           norm_fulfillment  perception_severity  \
# norm_fulfillment                  1.000000             0.853534
# perception_severity               0.853534             1.000000
# perception_vulnerability          0.792727             0.809409
#
#                           perception_vulnerability
# norm_fulfillment                          0.792727
# perception_severity                       0.809409
# perception_vulnerability                  1.000000

# %%
features = ["behavior_sexualRisk", "behavior_eating", "behavior_personalHygine", "intention_aggregation", "attitude_consistency"]

# %%
import matplotlib.pyplot as plt
for x in features:
    plt.boxplot(data[x])
    plt.ylabel(x)
    plt.show()

# %%
for x in features:
    plt.hist(data[x], bins = 15)
    plt.label
    plt.show()

# %%
import seaborn as sns
sns.pairplot(data[["behavior_sexualRisk", "behavior_eating", "behavior_personalHygine", "intention_aggregation", "attitude_consistency"]] )

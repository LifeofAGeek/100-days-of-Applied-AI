# %% [markdown]
# <a href="https://colab.research.google.com/github/LifeofAGeek/100-days-of-Applied-AI/blob/master/dipAssignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
from io import BytesIO
from PIL import Image

uploaded = files.upload()
im = Image.open(BytesIO(uploaded['download.png']))
# Out:
#      <input type="file" id="files-7ea8fce8-956c-4629-bccf-1d53a1c2f3f2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ea8fce8-956c-4629-bccf-1d53a1c2f3f2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving download.png to download (1).png

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
from google.colab.patches import cv2_imshow
img = cv2.imread('download.png',0)
rows,cols = img.shape
print(rows, cols)

plt.imshow(img,cmap="gray")
plt.show()

print(img[200:210,201:210])
# Out:
# 469 388
# [[57 65 65 77 66 57 57 57 57]
#  [66 66 66 57 52 50 51 51 51]
#  [66 66 66 57 52 50 51 51 51]
#  [65 57 57 41 41 41 51 51 51]
#  [58 57 57 51 51 51 51 41 41]
#  [57 66 66 66 67 56 50 51 41]
#  [58 66 66 67 76 67 57 51 51]
#  [51 51 51 51 66 66 57 57 57]
#  [34 28 28 28 35 50 58 57 57]
#  [34 28 28 28 35 50 58 57 57]]

# %%
#thresholding
plt.imshow(img)
plt.show()

threshVal=120
img1=np.zeros((img.shape))
print(img1.shape)

img1[img>threshVal]=255

#img1[img1<=threshVal]=0

plt.subplot(1,3,1) #row,col,area
plt.imshow(img,cmap="gray")
plt.subplot(1,3,2)
plt.imshow(img1,cmap="gray")
# Out:
# (469, 388)

# %%
img2=255-img1
plt.subplot(1,3,3)
plt.imshow(img2,cmap="gray")
plt.show()

# %%
x=np.array([10, 12, 34, 10, 40])
z=x>10
print(x[z])
# Out:
# [12 34 40]

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('gray.png',0)
#127: threshold value
#255 : max threshold value
#thresh_binary : type of threshold
ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
ret,thresh2 = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
ret,thresh3 = cv2.threshold(img,127,200,cv2.THRESH_TRUNC)
ret,thresh4 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO)
ret,thresh5 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO_INV)
ret,thresh6 = cv2.threshold(img,127,255,cv2.CAP_PROP_CONTRAST)

titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV','CAP_PROP_CONTRAST']
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5, thresh6]

for i in range(7):
    plt.subplot(3,3,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()
'''
print(img[0,:])
print(thresh1[0,:])
print(thresh3[0,:])
print(thresh4[0,:])
print(thresh5[0,:])
print(thresh6[0,:])
'''

# %%
#histogram
img = cv2.imread('download.png',0)
hist = cv2.calcHist([img],[0],None,[256],[0,256])
plt.plot(hist)
plt.show()

plt.hist(img.ravel(),256,[0,256])
plt.show()
